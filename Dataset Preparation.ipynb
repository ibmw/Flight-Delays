# %%
import pandas as pd
import glob

# %% [markdown]
# # Trainning Dataset : Ontime 2016

# %%
# Loading the data in one dataframe
list_csv = []
for filename in glob.glob('./data/*.csv'):
    # low_memory=false to avoid Mixed types error when reading csv files
    df = pd.read_csv(filename, skiprows = 0, low_memory=False)  
    list_csv.append(df)

mydf = pd.concat(list_csv)
mydf.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 0  2016        1      1             3            7  2016-01-03             F9
# 1  2016        1      1             3            7  2016-01-03             F9
# 2  2016        1      1             3            7  2016-01-03             F9
# 3  2016        1      1             3            7  2016-01-03             F9
# 4  2016        1      1             3            7  2016-01-03             F9
#
#   ORIGIN                ORIGIN_CITY_NAME DEST     ...      ARR_DEL15  FLIGHTS  \
# 0    DEN                      Denver, CO  CID     ...            0.0      1.0
# 1    PBI  West Palm Beach/Palm Beach, FL  DEN     ...            1.0      1.0
# 2    TTN                     Trenton, NJ  RDU     ...            0.0      1.0
# 3    RDU              Raleigh/Durham, NC  TTN     ...            0.0      1.0
# 4    TTN                     Trenton, NJ  ORD     ...            1.0      1.0
#
# ...

# %%
mydf = mydf.drop("Unnamed: 25", axis=1)
cause_delay = ["CARRIER_DELAY", "WEATHER_DELAY", "NAS_DELAY", "SECURITY_DELAY", "LATE_AIRCRAFT_DELAY"]
#mydf[cause_delay] = mydf[cause_delay].fillna(0).astype("int")
mydf = mydf.drop(cause_delay, axis=1)
mydf[["DISTANCE", "FLIGHTS"]] = mydf[["DISTANCE", "FLIGHTS"]].astype("int")

# %%
mydf = mydf.dropna(axis=0, how='any')
mydf[["DEP_DEL15", "ARR_DEL15"]] = mydf[["DEP_DEL15", "ARR_DEL15"]].astype("int")

# %%
mydf.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 0  2016        1      1             3            7  2016-01-03             F9
# 1  2016        1      1             3            7  2016-01-03             F9
# 2  2016        1      1             3            7  2016-01-03             F9
# 3  2016        1      1             3            7  2016-01-03             F9
# 4  2016        1      1             3            7  2016-01-03             F9
#
#   ORIGIN                ORIGIN_CITY_NAME DEST              DEST_CITY_NAME  \
# 0    DEN                      Denver, CO  CID  Cedar Rapids/Iowa City, IA
# 1    PBI  West Palm Beach/Palm Beach, FL  DEN                  Denver, CO
# 2    TTN                     Trenton, NJ  RDU          Raleigh/Durham, NC
# 3    RDU              Raleigh/Durham, NC  TTN                 Trenton, NJ
# 4    TTN                     Trenton, NJ  ORD                 Chicago, IL
#
# ...

# %%
mydf[["ARR_TIME", "DEP_TIME"]] = mydf[["ARR_TIME", "DEP_TIME"]].astype("int")

# %%
mydf.to_csv('delay16.csv', index=False)

# %% [markdown]
# # Test Dataset : Ontime 2017

# %%
# Loading the data in one dataframe
list_csv = []
for filename in glob.glob('./data/2017/*.csv'):
    # low_memory=false to avoid Mixed types error when reading csv files
    df = pd.read_csv(filename, skiprows = 0, low_memory=False)  
    list_csv.append(df)

mydf = pd.concat(list_csv)
mydf.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 0  2017        1      1             7            6  2017-01-07             AA
# 1  2017        1      1             8            7  2017-01-08             AA
# 2  2017        1      1             9            1  2017-01-09             AA
# 3  2017        1      1            10            2  2017-01-10             AA
# 4  2017        1      1            11            3  2017-01-11             AA
#
#   ORIGIN ORIGIN_CITY_NAME DEST     ...      ARR_DEL15  FLIGHTS  DISTANCE  \
# 0    BOS       Boston, MA  LAX     ...            1.0      1.0    2611.0
# 1    BOS       Boston, MA  LAX     ...            0.0      1.0    2611.0
# 2    BOS       Boston, MA  LAX     ...            1.0      1.0    2611.0
# 3    BOS       Boston, MA  LAX     ...            0.0      1.0    2611.0
# 4    BOS       Boston, MA  LAX     ...            1.0      1.0    2611.0
#
# ...

# %%
mydf = mydf.drop("Unnamed: 25", axis=1)
cause_delay = ["CARRIER_DELAY", "WEATHER_DELAY", "NAS_DELAY", "SECURITY_DELAY", "LATE_AIRCRAFT_DELAY"]
#mydf[cause_delay] = mydf[cause_delay].fillna(0).astype("int")
mydf = mydf.drop(cause_delay, axis=1)
mydf[["DISTANCE", "FLIGHTS"]] = mydf[["DISTANCE", "FLIGHTS"]].astype("int")

# %%
mydf = mydf.dropna(axis=0, how='any')
mydf[["DEP_DEL15", "ARR_DEL15"]] = mydf[["DEP_DEL15", "ARR_DEL15"]].astype("int")
mydf[["ARR_TIME", "DEP_TIME"]] = mydf[["ARR_TIME", "DEP_TIME"]].astype("int")

# %%
mydf.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE UNIQUE_CARRIER  \
# 0  2017        1      1             7            6  2017-01-07             AA
# 1  2017        1      1             8            7  2017-01-08             AA
# 2  2017        1      1             9            1  2017-01-09             AA
# 3  2017        1      1            10            2  2017-01-10             AA
# 4  2017        1      1            11            3  2017-01-11             AA
#
#   ORIGIN ORIGIN_CITY_NAME DEST   DEST_CITY_NAME  CRS_DEP_TIME  DEP_TIME  \
# 0    BOS       Boston, MA  LAX  Los Angeles, CA          1850      1857
# 1    BOS       Boston, MA  LAX  Los Angeles, CA          1850      1854
# 2    BOS       Boston, MA  LAX  Los Angeles, CA          1850      1917
# 3    BOS       Boston, MA  LAX  Los Angeles, CA          1903      1857
# 4    BOS       Boston, MA  LAX  Los Angeles, CA          1903      1856
#
# ...

# %%
mydf.to_csv('delay17.csv', index=False)
